# %% [markdown]
# # Подготовка файлов и программ

# %% [markdown]
# ## Установка HISAT2 (для выравниваия RNA-seq чтений на геном)

# %%
!apt-get install hisat2
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# hisat2 is already the newest version (2.2.1-3).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.

# %% [markdown]
# ## Установка sra-toolkit (для скачивания .fastq файлов из NCBI)

# %%
!apt-get install sra-toolkit
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   blends-common libkdf5-2 libncbi-vdb2 libncbi-wvdb2 med-config menu
# Suggested packages:
#   blends-doc menu-l10n gksu | kde-runtime | ktsuss
# The following NEW packages will be installed:
#   blends-common libkdf5-2 libncbi-vdb2 libncbi-wvdb2 med-config menu
#   sra-toolkit
# 0 upgraded, 7 newly installed, 0 to remove and 41 not upgraded.
# Need to get 8,290 kB of archives.
# After this operation, 23.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 menu amd64 2.1.47ubuntu4 [354 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 blends-common all 0.7.4ubuntu1 [15.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libkdf5-2 amd64 2.11.2+dfsg-4build2 [14.7 kB]
# ...

# %% [markdown]
# ## Установка FastQC

# %%
!java -version
# Out:
# openjdk version "11.0.28" 2025-07-15
# OpenJDK Runtime Environment (build 11.0.28+6-post-Ubuntu-1ubuntu122.04.1)
# OpenJDK 64-Bit Server VM (build 11.0.28+6-post-Ubuntu-1ubuntu122.04.1, mixed mode, sharing)

# %%
!apt-get install -y default-jre # устанавливаю java для FastQC
!java -version # проверяю
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   at-spi2-core ca-certificates-java default-jre-headless fonts-dejavu-core
#   fonts-dejavu-extra gsettings-desktop-schemas java-common libatk-bridge2.0-0
#   libatk-wrapper-java libatk-wrapper-java-jni libatk1.0-0 libatk1.0-data
#   libatspi2.0-0 libpcsclite1 libxcomposite1 libxtst6 libxxf86dga1
#   openjdk-11-jre openjdk-11-jre-headless session-migration x11-utils
# Suggested packages:
#   pcscd libnss-mdns fonts-ipafont-gothic fonts-ipafont-mincho
#   fonts-wqy-microhei | fonts-wqy-zenhei fonts-indic mesa-utils
# The following NEW packages will be installed:
#   at-spi2-core ca-certificates-java default-jre default-jre-headless
#   fonts-dejavu-core fonts-dejavu-extra gsettings-desktop-schemas java-common
#   libatk-bridge2.0-0 libatk-wrapper-java libatk-wrapper-java-jni libatk1.0-0
# ...

# %%
!wget https://www.bioinformatics.babraham.ac.uk/projects/fastqc/fastqc_v0.11.9.zip # скачаиваю FastQC с официального сайта
!unzip fastqc_v0.11.9.zip # распаковываю
!chmod a+x FastQC/fastqc # даю права на выполнение (a+x - добавить право на выполнение для всех пользователей). fastqc - имя исполняемого файла в папке FastQC
# Out:
# --2025-11-12 14:43:24--  https://www.bioinformatics.babraham.ac.uk/projects/fastqc/fastqc_v0.11.9.zip
# Resolving www.bioinformatics.babraham.ac.uk (www.bioinformatics.babraham.ac.uk)... 149.155.133.4
# Connecting to www.bioinformatics.babraham.ac.uk (www.bioinformatics.babraham.ac.uk)|149.155.133.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10249221 (9.8M) [application/zip]
# Saving to: ‘fastqc_v0.11.9.zip’
#
# fastqc_v0.11.9.zip  100%[===================>]   9.77M  11.6MB/s    in 0.8s
#
# 2025-11-12 14:43:25 (11.6 MB/s) - ‘fastqc_v0.11.9.zip’ saved [10249221/10249221]
#
# Archive:  fastqc_v0.11.9.zip
#   inflating: FastQC/cisd-jhdf5.jar
#    creating: FastQC/Configuration/
#   inflating: FastQC/Configuration/adapter_list.txt
#   inflating: FastQC/Configuration/contaminant_list.txt
#   inflating: FastQC/Configuration/limits.txt
#   inflating: FastQC/fastqc
#   inflating: FastQC/fastqc_icon.ico
#    creating: FastQC/Help/
# ...

# %%
!./FastQC/fastqc --help # проверяю установку
# Out:
#             FastQC - A high throughput sequence QC analysis tool
#
# SYNOPSIS
#
# 	fastqc seqfile1 seqfile2 .. seqfileN
#
#     fastqc [-o output dir] [--(no)extract] [-f fastq|bam|sam]
#            [-c contaminant file] seqfile1 .. seqfileN
#
# DESCRIPTION
#
#     FastQC reads a set of sequence files and produces from each one a quality
#     control report consisting of a number of different modules, each one of
#     which will help to identify a different potential type of problem in your
#     data.
#
#     If no files to process are specified on the command line then the program
#     will start as an interactive graphical application.  If files are provided
#     on the command line then the program will run with no user interaction
#     required.  In this mode it is suitable for inclusion into a standardised
#     analysis pipeline.
#
#     The options for the program as as follows:
#
#     -h --help       Print this help file and exit
#
# ...

# %% [markdown]
# ## Установка HTSeq-count

# %%
!pip install HTSeq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 74.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 85.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Скачиваие RNA-seq данных

# %% [markdown]
# * Перепрограммированные образцы: 	SRR3414629, SRR3414630, SRR3414631
# * Контрольные образцы:		SRR3414635, SRR3414636, SRR3414637

# %%
%%bash
# все образцы в одном списке
all_samples=("SRR3414629" "SRR3414630" "SRR3414631" "SRR3414635" "SRR3414636" "SRR3414637")

for sample in "${all_samples[@]}"
do
    # извлекаю RNA-seq данные из SRA в формате FASTQ
    time fastq-dump --split-files $sample # time - время выполнения, --split-files - разделить парные чтения на разные файлы: _1.fastq (forward) и 2.fastq (reverse)
done
# Out:
# Read 21106089 spots for SRR3414629
# Written 21106089 spots for SRR3414629
# Read 15244711 spots for SRR3414630
# Written 15244711 spots for SRR3414630
# Read 24244069 spots for SRR3414631
# Written 24244069 spots for SRR3414631
# Read 20956475 spots for SRR3414635
# Written 20956475 spots for SRR3414635
# Read 20307147 spots for SRR3414636
# Written 20307147 spots for SRR3414636
# Read 20385570 spots for SRR3414637
# Written 20385570 spots for SRR3414637
# real	4m51.458s
# user	3m43.226s
# sys	0m12.038s
#
# real	3m42.476s
# user	2m49.609s
# sys	0m7.753s
#
# real	5m48.909s
# user	4m27.089s
# sys	0m12.721s
#
# real	5m0.739s
# user	3m51.593s
# sys	0m11.860s
#
# real	4m52.753s
# user	3m44.570s
# sys	0m11.710s
#
# real	4m42.909s
# user	3m36.244s
# sys	0m11.273s

# %% [markdown]
# Создались только файлы _1.fastq, значит данные Single-End (не парные)

# %% [markdown]
# ## Скачивание генома мыши mm10 (проиндексированный для HISAT2)

# %%
!wget https://genome-idx.s3.amazonaws.com/hisat/mm10_genome.tar.gz #скачивание
!tar -xzvf mm10_genome.tar.gz                                      #распаковка -x - извлечь, -z - распаковать gzip, -v - подробный вывод, -f - указать файл архива
# Out:
# --2025-11-12 15:24:43--  https://genome-idx.s3.amazonaws.com/hisat/mm10_genome.tar.gz
# Resolving genome-idx.s3.amazonaws.com (genome-idx.s3.amazonaws.com)... 54.231.169.73, 52.216.220.105, 52.217.133.121, ...
# Connecting to genome-idx.s3.amazonaws.com (genome-idx.s3.amazonaws.com)|54.231.169.73|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3804366597 (3.5G) [binary/octet-stream]
# Saving to: ‘mm10_genome.tar.gz’
#
# mm10_genome.tar.gz  100%[===================>]   3.54G  21.7MB/s    in 2m 26s
#
# 2025-11-12 15:27:09 (24.9 MB/s) - ‘mm10_genome.tar.gz’ saved [3804366597/3804366597]
#
# mm10/
# mm10/genome.8.ht2
# mm10/genome.5.ht2
# mm10/make_mm10.sh
# mm10/genome.7.ht2
# mm10/genome.6.ht2
# mm10/genome.4.ht2
# mm10/genome.3.ht2
# mm10/genome.1.ht2
# mm10/genome.2.ht2

# %% [markdown]
# ## Скачивание аннотации генов GENCODE для генома мыши mm10

# %%
!wget http://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_mouse/release_M25/gencode.vM25.annotation.gtf.gz  # скачивание
!gzip -d gencode.vM25.annotation.gtf.gz                                                                    # распаковка, -d - распаковать
# Out:
# --2025-11-22 14:18:02--  http://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_mouse/release_M25/gencode.vM25.annotation.gtf.gz
# Resolving ftp.ebi.ac.uk (ftp.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.ebi.ac.uk (ftp.ebi.ac.uk)|193.62.193.165|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28542432 (27M) [application/x-gzip]
# Saving to: ‘gencode.vM25.annotation.gtf.gz’
#
# gencode.vM25.annota 100%[===================>]  27.22M  19.6MB/s    in 1.4s
#
# 2025-11-22 14:18:03 (19.6 MB/s) - ‘gencode.vM25.annotation.gtf.gz’ saved [28542432/28542432]

# %% [markdown]
# ## Установка MultiQC

# %%
!pip install git+https://github.com/ewels/MultiQC.git
!multiqc --version
# Out:
# ...
#   Cloning https://github.com/ewels/MultiQC.git to /tmp/pip-req-build-47vsk4w_
#   Running command git clone --filter=blob:none --quiet https://github.com/ewels/MultiQC.git /tmp/pip-req-build-47vsk4w_
#   Resolved https://github.com/ewels/MultiQC.git to commit 8b1795d7e8a82ee3320902d4bc77f09e597c1b1d
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.6/39.6 MB 18.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 75.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Выравнивание чтений

# %% [markdown]
# ## FastQC и MultiQC анализ

# %%
%%bash
all_samples=("SRR3414629" "SRR3414630" "SRR3414631" "SRR3414635" "SRR3414636" "SRR3414637")

for sample in "${all_samples[@]}"
do
    ./FastQC/fastqc "/content/${sample}_1.fastq"
done
# Out:
# Analysis complete for SRR3414629_1.fastq
# Analysis complete for SRR3414630_1.fastq
# Analysis complete for SRR3414631_1.fastq
# Analysis complete for SRR3414635_1.fastq
# Analysis complete for SRR3414636_1.fastq
# Analysis complete for SRR3414637_1.fastq
# Started analysis of SRR3414629_1.fastq
# Approx 5% complete for SRR3414629_1.fastq
# Approx 10% complete for SRR3414629_1.fastq
# Approx 15% complete for SRR3414629_1.fastq
# Approx 20% complete for SRR3414629_1.fastq
# Approx 25% complete for SRR3414629_1.fastq
# Approx 30% complete for SRR3414629_1.fastq
# Approx 35% complete for SRR3414629_1.fastq
# Approx 40% complete for SRR3414629_1.fastq
# Approx 45% complete for SRR3414629_1.fastq
# Approx 50% complete for SRR3414629_1.fastq
# Approx 55% complete for SRR3414629_1.fastq
# Approx 60% complete for SRR3414629_1.fastq
# Approx 65% complete for SRR3414629_1.fastq
# Approx 70% complete for SRR3414629_1.fastq
# Approx 75% complete for SRR3414629_1.fastq
# ...

# %%
%%bash
# создаю папку для отчетов FastQC
mkdir fastqc_reports

# переношу все отчеты FastQC в эту папку
# через интерфейс удалила fastqc_v0.11.9.zip (этот файл больше не нужен), чтобы он не попал в папку с отчетами FastQC
mv *.html *.zip fastqc_reports/

# запускаею MultiQC на папке fastqc_reports
multiqc fastqc_reports/ -o multiqc_results # -o - папка для сохранения результатов
# Out:
# /// MultiQC 🔍 v1.33.dev0
#
#        file_search | Search path: /content/fastqc_reports
#
#             fastqc | Found 6 reports
#
#      write_results | Data        : multiqc_results/multiqc_data
#      write_results | Report      : multiqc_results/multiqc_report.html
#            multiqc | MultiQC complete

# %% [markdown]
# ## Работа с HISAT2

# %%
%%bash
cd /content # перешла в нужную папку
all_samples=("SRR3414629" "SRR3414630" "SRR3414631" "SRR3414635" "SRR3414636" "SRR3414637")
for sample in "${all_samples[@]}";
do
    # -p 3 - количество потоков, -x mm10/genome - путь к индексу референсного генома, -U - Single-End чтения, -S - указывает выходной SAM файл
    # 2> ${sample}.hisat - перенаправление стандартного потока диагностики
    time hisat2 -p 3 -x mm10/genome -U ${sample}_1.fastq -S ${sample}_1.sam 2> ${sample}.hisat # запуск hisat2

    # grep - поиск по шаблону
    # -P -
    # '^@|NH:i:1$' - шаблон поиска:
    # ^@ - строки, начинающиеся с @ (заголовки SAM файла)
    # | - логическое или
    # NH:i:1$ - строки, заканчивающиеся на NH:i:1 (уникальные выравнивания)
    grep -P '^@|NH:i:1$' ${sample}_1.sam > ${sample}.uniq.sam # отбираю только те чтения, которые откартировались уникально (флаг NH:i:1)

    rm -v ${sample}_1.sam # удаляю исходные SAM файлы
done
# Out:
# removed 'SRR3414629_1.sam'
# removed 'SRR3414630_1.sam'
# removed 'SRR3414631_1.sam'
# removed 'SRR3414635_1.sam'
# removed 'SRR3414636_1.sam'
# removed 'SRR3414637_1.sam'
# real	18m6.785s
# user	25m11.019s
# sys	1m50.320s
#
# real	12m57.021s
# user	18m5.597s
# sys	1m17.756s
#
# real	20m44.992s
# user	29m26.133s
# sys	2m4.021s
#
# real	16m54.635s
# user	23m48.621s
# sys	1m39.772s
#
# real	16m38.933s
# user	23m24.339s
# sys	1m38.592s
#
# real	16m25.316s
# user	23m9.723s
# sys	1m36.367s
# grep: write error: No space left on device

# %% [markdown]
# Закончилась память на последнем образце, удаляю ненужные файлы и запускаю для последнего образца еще раз

# %%
# удаляю ненужные fastq файлы
%%bash
for sample in SRR3414629 SRR3414630 SRR3414631 SRR3414635 SRR3414636;
do
    if [ -f "${sample}_1.fastq" ]; then
        rm -v ${sample}_1.fastq
    fi
done
# Out:
# removed 'SRR3414629_1.fastq'
# removed 'SRR3414630_1.fastq'
# removed 'SRR3414631_1.fastq'
# removed 'SRR3414635_1.fastq'
# removed 'SRR3414636_1.fastq'

# %%
# удаляю неполные файлы
!rm -v SRR3414637.uniq.sam
!rm -v SRR3414637.hisat
# Out:
# removed 'SRR3414637.uniq.sam'
# removed 'SRR3414637.hisat'

# %%
%%bash
time hisat2 -p 3 -x mm10/genome -U SRR3414637_1.fastq -S SRR3414637_1.sam 2> SRR3414637.hisat # hisat2
grep -P '^@|NH:i:1$' SRR3414637_1.sam > SRR3414637.uniq.sam # фильтрую
rm -v SRR3414637_1.sam SRR3414637_1.fastq # удаляю ненужные файлы
# Out:
# removed 'SRR3414637_1.sam'
# removed 'SRR3414637_1.fastq'
# real	16m50.020s
# user	23m7.296s
# sys	1m40.137s

# %% [markdown]
# Считаю кол-во уникально-картированных чтений

# %%
%%bash
all_samples=("SRR3414629" "SRR3414630" "SRR3414631" "SRR3414635" "SRR3414636" "SRR3414637")

for sample in "${all_samples[@]}";
do
    echo -n "$sample: "
    grep -v '^@' ${sample}.uniq.sam | wc -l # grep -v '^@' - исключает заголовки SAM файла
                                            # wc -l - подсчитывает количество строк
done
# Out:
# SRR3414629: 18573565
# SRR3414630: 13320505
# SRR3414631: 21159606
# SRR3414635: 18637053
# SRR3414636: 18032679
# SRR3414637: 18043406

# %% [markdown]
# ## HTSeq

# %%
%%bash
all_samples=("SRR3414629" "SRR3414630" "SRR3414631" "SRR3414635" "SRR3414636" "SRR3414637")

for sample in "${all_samples[@]}";
do
    time htseq-count --format=sam --stranded=no ${sample}.uniq.sam gencode.vM25.annotation.gtf > ${sample}.counts
    rm -v ${sample}.uniq.sam # удаляю SAM файл
done

# --format=sam - формат входного файла
#--stranded=no - данные не stranded (не учитывать цепь днк)
#> ${sample}.counts - файл для сохранения результатов подсчета
# Out:
# removed 'SRR3414629.uniq.sam'
# removed 'SRR3414630.uniq.sam'
# removed 'SRR3414631.uniq.sam'
# removed 'SRR3414635.uniq.sam'
# removed 'SRR3414636.uniq.sam'
# removed 'SRR3414637.uniq.sam'
# 100000 GFF lines processed.
# 200000 GFF lines processed.
# 300000 GFF lines processed.
# 400000 GFF lines processed.
# 500000 GFF lines processed.
# 600000 GFF lines processed.
# 700000 GFF lines processed.
# 800000 GFF lines processed.
# 900000 GFF lines processed.
# 1000000 GFF lines processed.
# 1100000 GFF lines processed.
# 1200000 GFF lines processed.
# 1300000 GFF lines processed.
# 1400000 GFF lines processed.
# 1500000 GFF lines processed.
# 1600000 GFF lines processed.
# 1700000 GFF lines processed.
# 1800000 GFF lines processed.
# 1872052 GFF lines processed.
# 100000 alignment records processed.
# 200000 alignment records processed.
# 300000 alignment records processed.
# 400000 alignment records processed.
# 500000 alignment records processed.
# 600000 alignment records processed.
# ...

# %% [markdown]
# ## Статистика

# %%
!grep '^_' SRR3414636.counts
# Out:
# __no_feature	1347210
# __ambiguous	742802
# __too_low_aQual	0
# __not_aligned	0
# __alignment_not_unique	0

# %%
%%bash
all_samples=("SRR3414629" "SRR3414630" "SRR3414631" "SRR3414635" "SRR3414636" "SRR3414637")
sample_types=("Перепрограммированный" "Перепрограммированный" "Перепрограммированный" "Контрольный" "Контрольный" "Контрольный")

echo "ID | Тип образца | Общее кол-во исходных чтений | Кол-во и процент чтений, которые были успешно откартированы на геном | Кол-во и процент уникально откартированных чтений | Общее кол-во чтений, которые попали на гены"

for i in {0..5};
do
    sample_id="${all_samples[i]}"
    sample_type="${sample_types[i]}" # тип образца

    # awk '{print $1}' берет нужную колонку и возвращает значение из нее
    total_reads=$(grep "reads; of these" ${sample_id}.hisat | awk '{print $1}') # всего чтений

    # процент успешно откартированных чтений. tr -d '%' - удалить % из строки
    mapped_percent=$(grep "overall alignment rate" ${sample_id}.hisat | awk '{print $1}'| tr -d '%')
    # количество откартированных чтений. bc - выполнить математические вычисления
    mapped_reads=$(echo "scale=0; $total_reads * $mapped_percent / 100" | bc)

    # количество и процент уникально откартированных чтений
    uniquely_mapped=$(grep "aligned exactly 1 time" ${sample_id}.hisat | awk '{print $1}')
    uniquely_mapped_percent=$(grep "aligned exactly 1 time" ${sample_id}.hisat | awk '{print $2}' | tr -d '()%')

    # общее количество чтений, которые попали на гены (сумма всех генов, исключая __no_feature __ambiguous)
    reads_on_genes=$(grep -v "^__" ${sample_id}.counts | awk '{sum += $2} END {print sum}')

    # Форматируем вывод в виде таблицы
    echo "$sample_id | $sample_type | $total_reads | $mapped_reads ($mapped_percent%) | $uniquely_mapped ($uniquely_mapped_percent%) | $reads_on_genes"
done
# Out:
# ID | Тип образца | Общее кол-во исходных чтений | Кол-во и процент чтений, которые были успешно откартированы на геном | Кол-во и процент уникально откартированных чтений | Общее кол-во чтений, которые попали на гены
# SRR3414629 | Перепрограммированный | 21106089 | 20865479 (98.86%) | 18573565 (88.00%) | 16224313
# SRR3414630 | Перепрограммированный | 15244711 | 15077019 (98.90%) | 13320505 (87.38%) | 11583775
# SRR3414631 | Перепрограммированный | 24244069 | 23965262 (98.85%) | 21159606 (87.28%) | 18613501
# SRR3414635 | Контрольный | 20956475 | 20715475 (98.85%) | 18637053 (88.93%) | 16463013
# SRR3414636 | Контрольный | 20307147 | 20073614 (98.85%) | 18032679 (88.80%) | 15942667
# SRR3414637 | Контрольный | 20385570 | 20149097 (98.84%) | 18043406 (88.51%) | 15914380

# %% [markdown]
# ## ALL.counts

# %%
import pandas as pd

sample_mapping = [
    ("SRR3414629", "r1"),
    ("SRR3414630", "r2"),
    ("SRR3414631", "r3"),
    ("SRR3414635", "c1"),
    ("SRR3414636", "c2"),
    ("SRR3414637", "c3")
]

dataset = []
for original_name, new_name in sample_mapping:
    df = pd.read_csv(f"{original_name}.counts", sep="\t", header=None, names=[new_name])
    dataset.append(df)

# объединение по столбцам
combined_data = pd.concat(dataset, axis=1)

# сохранение
combined_data.to_csv("ALL.counts", sep='\t', index=True)

print(combined_data.head())
print(f"\nРазмер таблицы: {combined_data.shape}")
# Out:
#                           r1     r2     r3     c1     c2     c3
# ENSMUSG00000000001.4    4507   3964   5757   3466   3532   4078
# ENSMUSG00000000003.15      0      0      0      0      0      0
# ENSMUSG00000000028.15    348    275    472    152    137    152
# ENSMUSG00000000031.16  64722  33333  65188  55721  48392  56187
# ENSMUSG00000000037.17     79     70     92     43     44     53
#
# Размер таблицы: (55406, 6)

# %% [markdown]
# Фильтрую рРНК

# %%
# извлекаею ENSEMBL ID генов с биотипом rRNA из генома мыши
# - grep -i: поиск без учета регистра
# - grep -o: вывод только совпавшей части строки
# - cut -d'"' -f2: разделитель кавычка, берется 2-е поле (id между кавычками)
# - sort -u: только уникальные id
!grep -i "gene_type \"rRNA\"" gencode.vM25.annotation.gtf | grep -o "gene_id \"[^\"]*\"" | cut -d'"' -f2 | sort -u > rrna_ensembl_ids.txt

# %%
#-v - оставить строки, которые не содержат паттерн
#-i - игнорировать регистр
#-f rrna_keywords.txt - брать паттерны для поиска из файла
# ALL.counts - исходный файл с данными
#> all.counts_no_rrna - перенаправить результат в новый файл
!grep -v -i -f rrna_ensembl_ids.txt ALL.counts > ALL.counts_no_rrna

# %%
%%bash
# сравнение количества строк в исходном и отфильтрованном файле
echo "Исходный файл ALL.counts:"
wc -l ALL.counts

echo "Файл без рРНК ALL.counts_no_rrna:"
wc -l ALL.counts_no_rrna
# Out:
# Исходный файл ALL.counts:
# 55407 ALL.counts
# Файл без рРНК ALL.counts_no_rrna:
# 55053 ALL.counts_no_rrna

# %%
# удаляю исходный ALL.counts
!rm ALL.counts
# переименовываю файл без рРНК в ALL.counts
!mv ALL.counts_no_rrna ALL.counts

# %% [markdown]
# # Бонус

# %%
# установка BiocManager
if (!require("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

# установка DESeq2
BiocManager::install("DESeq2")

# установка пакета для визуализации
install.packages("pheatmap")

# загрузка библиотек в текущую сессию
library(DESeq2)
library(pheatmap)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.22 (BiocManager 1.30.27), R 4.5.2 (2025-10-31)
#
# Installing package(s) 'BiocVersion', 'DESeq2'
#
# also installing the dependencies ‘XVector’, ‘formatR’, ‘abind’, ‘SparseArray’, ‘lambda.r’, ‘futile.options’, ‘Seqinfo’, ‘S4Arrays’, ‘DelayedArray’, ‘futile.logger’, ‘snow’, ‘BH’, ‘S4Vectors’, ‘IRanges’, ‘GenomicRanges’, ‘SummarizedExperiment’, ‘BiocGenerics’, ‘Biobase’, ‘BiocParallel’, ‘matrixStats’, ‘locfit’, ‘MatrixGenerics’, ‘RcppArmadillo’
#
#
# Old packages: 'selectr'
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: S4Vectors
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
# ...

# %% [markdown]
# Создала файл ALL.info со следущим содержимым:
#
# ```
# id condition
# r1 SRR3414629 reprogramming
# r2 SRR3414630 reprogramming
# r3 SRR3414631 reprogramming
# c1 SRR3414635 control
# c2 SRR3414636 control
# c3 SRR3414637 control
# ```

# %%
# загрузка данных из ALL.info с информацией по каждому образцу
info   <- read.table("ALL.info", header=TRUE, sep="")

# загрузка данных об экспрессии. на выходе - матрица для DESeq2
# row.names=1 - первая колонка (с ensenbl id) станет названиями строк
counts <- as.matrix(read.table("ALL.counts", header=TRUE, row.names=1))

# cоздание объекта DESeqDataSet
# countData = counts - матрица с количеством ридов для каждого гена
# colData = info - данные, описывающие каждый образец
# design = ~ condition - cравниваnm экспрессию генов между группами, определенными в колонке condition
dds <- DESeqDataSetFromMatrix(countData = counts, colData = info, design = ~ condition)
# Out:
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”

# %%
head(info)
# Out:
#    id         condition
# r1 SRR3414629 reprogramming
# r2 SRR3414630 reprogramming
# r3 SRR3414631 reprogramming
# c1 SRR3414635 control
# c2 SRR3414636 control
# c3 SRR3414637 control

# %%
head(counts)
# Out:
#                       r1    r2    r3    c1    c2    c3
# ENSMUSG00000000001.4   4507  3964  5757  3466  3532  4078
# ENSMUSG00000000003.15     0     0     0     0     0     0
# ENSMUSG00000000028.15   348   275   472   152   137   152
# ENSMUSG00000000031.16 64722 33333 65188 55721 48392 56187
# ENSMUSG00000000037.17    79    70    92    43    44    53
# ENSMUSG00000000049.11     4     1     1    10     8    11

# %%
# установка контрольной группы: группа control является контрольной(reference)
dds$condition <- relevel(dds$condition, ref="control")

# запуск анализа
# сравнивается reprogrammed и control для каждого гена
# для каждого гена считается: средняя экспрессия, изменение экспрессии, p-value
dds <- DESeq(dds)

# извлечение результатов
# alpha=0.01 - порог значимости для p-value
res <- results(dds, alpha=0.01)
# Out:
# estimating size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing

# %% [markdown]
# ## Heatmap

# %%
# тепловая карта (heatmap) для визуализации сходства между образцами на основе экспрессии
rld <- rlog(dds) # стабилизация дисперсии данных
sampleDists <- dist(t(assay(rld))) # матрица расстояний
sampleDistMatrix <- as.matrix(sampleDists) # преобразование объекта "dist" в матрицу для построения heatmap
pheatmap(sampleDistMatrix, clustering_distance_rows=sampleDists, clustering_distance_cols=sampleDists) # построение heatmap
# Out:
# plot without title

# %% [markdown]
# Все контрольные образцы похожи между собой, а перепрограммированные образцы - между собой. Такие кластеры доказывают присутствие дифференицальной экспрессии и хорошее качество эксперимента.

# %% [markdown]
# ## plotMA

# %%
# Установка и загрузка biomaRt (для того, чтобы получить названия генов по ENSEBLE ID)
if (!require("biomaRt", quietly = TRUE)) {
    BiocManager::install("biomaRt")
}
library(biomaRt)
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.22 (BiocManager 1.30.27), R 4.5.2 (2025-10-31)
#
# Installing package(s) 'biomaRt'
#
# also installing the dependencies ‘plogr’, ‘png’, ‘Biostrings’, ‘RSQLite’, ‘KEGGREST’, ‘filelock’, ‘AnnotationDbi’, ‘BiocFileCache’
#
#
# Old packages: 'selectr'

# %%
# cортировка результатов по p-value (padj)
# самые значимые - вверху списка
resOrdered <- res[order(res$padj),]

# отбор статистически значимых генов
resSignificant <- subset(resOrdered, padj < 0.01)

# подключение к базе данных мыши
ensembl <- useMart("ensembl", dataset = "mmusculus_gene_ensembl")

# получение ENSEMBL ID (убираю версии .1, .2 ...)
ensembl_ids <- gsub("\\..*", "", rownames(resSignificant))

# получение названий генов
gene_names <- getBM(
    attributes = c("ensembl_gene_id", "external_gene_name"),
    filters = "ensembl_gene_id",
    values = ensembl_ids,
    mart = ensembl
)

# аннотированная таблица
resSignificant_annotated <- as.data.frame(resSignificant)
resSignificant_annotated$gene_name <- gene_names$external_gene_name[match(ensembl_ids, gene_names$ensembl_gene_id)]

# название гена в первой колонке
resSignificant_annotated <- resSignificant_annotated[, c("gene_name", "baseMean", "log2FoldChange", "lfcSE", "stat", "pvalue", "padj")]

# сохранение значимых генов в файл
# sep="\t" - табуляция как разделитель
# row.names=TRUE - сохранять названия генов (ENSEMBL ID)
# quote=FALSE - не заключать значения в кавычки
write.table(resSignificant_annotated, "differentially_expressed_genes.txt", sep="\t", row.names=TRUE, quote=FALSE)

# %%
de_genes <- read.table("/content/differentially_expressed_genes.txt", header=TRUE, sep="\t")
head(de_genes)
# Out:
#                       gene_name baseMean log2FoldChange lfcSE     stat
# ENSMUSG00000000303.12 Cdh1      2836.699 5.844462       0.1432886 40.78805
# ENSMUSG00000025608.9  Podxl     4423.243 8.302610       0.1967211 42.20499
# ENSMUSG00000054889.10 Dsp       6930.743 4.650861       0.1137541 40.88521
# ENSMUSG00000097767.8  Miat      4122.554 6.584034       0.1498966 43.92384
# ENSMUSG00000045545.8  Krt14     4116.008 9.134795       0.2387958 38.25358
# ENSMUSG00000047586.4  Nccrp1    2415.928 7.427786       0.1968443 37.73432
#                       pvalue        padj
# ENSMUSG00000000303.12  0.000000e+00  0.000000e+00
# ENSMUSG00000025608.9   0.000000e+00  0.000000e+00
# ENSMUSG00000054889.10  0.000000e+00  0.000000e+00
# ENSMUSG00000097767.8   0.000000e+00  0.000000e+00
# ENSMUSG00000045545.8  3.626442e-320 1.498373e-316
# ENSMUSG00000047586.4  1.359748e-311 4.681840e-308

# %%
# Построение MA-plot для визуализации дифференциальной экспрессии
plotMA(res, ylim=c(-10,10))
# Out:
# Plot with title “”

# %% [markdown]
# Синим цветом показаны те гены, в которых значительно изменился уровень экспрессии. Серым цветом показаны гены, в которых не произошло статистически значимых измений уровня экспрессии. Из графика видно, что множество генов значимо изменили экспрессию, наблюдаются сильные изменения - log2FC до 10 (изменение в 1000+ раз)

# %% [markdown]
# ## Тепловая карта для 20 самых экспрессированных генов

# %%
# counts(dds, normalized=TRUE) - нормализованные counts
# rowMeans() - средняя экспрессия для каждого гена по всем образцам
# order(..., decreasing=TRUE) - сортировка по убыванию экспрессии
# [1:20] - 20 самых экспрессированных генов
select <- order(rowMeans(counts(dds, normalized=TRUE)), decreasing=TRUE)[1:20]

# colData(dds) - информация об образцах из DESeqDataSet
# [,c("condition","id")] - только колонки condition и id
df <- as.data.frame(colData(dds)[,c("condition","id")])

# построение тепловой карты:
pheatmap(assay(rld)[select,],
         cluster_rows=FALSE,
         show_rownames=FALSE,
         cluster_cols=FALSE,
         annotation_col=df)
# Out:
# plot without title

# %% [markdown]
# Из графика видно, что гены равномерно экспрессированы во всех образцах, нет разделения на контроль и перепрограммирование. Это подтверждает хорошее качество данных, так как наиболее экспрессированные гены связаны с базовыми процессами, и их экспрессия отличается слабо.

# %% [markdown]
# ## Для нескольких генов, которые наиболее значимо поменяли свою экспрессию - графики со значениями "Normalized counts" в контрольных и перепрограммированных образцах

# %%
# топ 3 значимых гена
head(de_genes, 3)
# Out:
#                       gene_name baseMean log2FoldChange lfcSE     stat
# ENSMUSG00000000303.12 Cdh1      2836.699 5.844462       0.1432886 40.78805
# ENSMUSG00000025608.9  Podxl     4423.243 8.302610       0.1967211 42.20499
# ENSMUSG00000054889.10 Dsp       6930.743 4.650861       0.1137541 40.88521
#                       pvalue padj
# ENSMUSG00000000303.12 0      0
# ENSMUSG00000025608.9  0      0
# ENSMUSG00000054889.10 0      0

# %%
genes <- c("ENSMUSG00000000303.12", "ENSMUSG00000025608.9", "ENSMUSG00000054889.10")

for (gene in genes) {
  gene_name <- de_genes[gene, "gene_name"] # получаю название гена
  plotCounts(dds, gene=gene, intgroup="condition", main=gene_name)
}
# Out:
# Plot with title “Cdh1”
# Plot with title “Podxl”
# Plot with title “Dsp”

# %% [markdown]
# На всех графиках видно четкое разделение между группами, при этом уровень экспрессии в reprogramming в несколько раз выше чем в control. Графики демонстрируют значимую разницу уровней экспрессии.
